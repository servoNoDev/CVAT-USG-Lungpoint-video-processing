# %%
import pandas as pd
import cv2
import os
import json
import string
import random as rand
import ast
from typing import Any, List, Tuple, Union
import random

# %%
CVAT_FOLDER_PATH = "/home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip"
df_videos = pd.read_pickle("/home/mh731nk/_data/experiments_tmp/data/revision_8/video.pkl", 'zip')
df_polygons = pd.read_json('/home/mh731nk/_data/experiments_tmp/data/revision_8/lp_polygons.json', orient='index')

# %% [markdown]
# # Video drawer
# Draw polygons and bountingboxes to original video

# %%
import cv2
import numpy as np
import pandas as pd
import os

## FUNCTION TO DRAW POLYGONS ON VIDEO
def draw_polygons_on_video(
    df_all_labels,
    original_videos_folder_path,
    video_df_row,
    store_path,
    polygon_col="interp_polygon",
    label_col="label_name",
    print_bbox=True
):
    """
    Reads one video from disk, overlays annotations on each frame, and writes the result to 'store_path'.

    Annotations with polygon data (in 'interp_polygon' or 'points') are drawn as polygons.
    If an annotation with the label "lungsliding" is present (representing a lungpoint), a vertical
    line is drawn at its x-coordinate spanning the entire height of the frame.

    Parameters
    ----------
    df_all_labels : pd.DataFrame
        Contains columns like [video_id, frame, interp_polygon (or points), label_name, ...].
        Each row corresponds to one annotation in one frame.
    original_videos_folder_path : str
        Path to the folder containing original videos.
    video_df_row : dict or pd.Series
        Contains metadata about which video to open. For example:
          {
            "video_id": ...,
            "video_subfolder_path": ...,
            "name_video": ...
          }
    store_path : str
        Where to save the annotated video (mp4).
    polygon_col : str
        The name of the column in df_all_labels that holds the polygon points. Default "interp_polygon".
    label_col : str
        The name of the column in df_all_labels that holds the label (e.g. "aline", "bline", "lungsliding", etc.).
        Default "label_name".
    """

    video_id = video_df_row["video_id"]
    print(f"Processing {video_id}")

    # 1) Filter df_all_labels for this video.
    df_video = df_all_labels[df_all_labels["video_id"] == video_id].copy()
    # Sort by frame (optional, helps for debugging)
    df_video.sort_values(by="frame", inplace=True)
    print(df_video)
    
    # 2) Build the path to the original video.
    folders_scan = [x for x in os.walk(
        os.path.join(original_videos_folder_path, video_df_row["video_subfolder_path"], 'data')
    )]
    if not folders_scan or not folders_scan[0][1]:
        raise ValueError("No subfolders found in data directory.")

    video_folder = folders_scan[0][1][0]
    path_video_folder = os.path.join(
        original_videos_folder_path,
        video_df_row["video_subfolder_path"],
        'data',
        video_folder
    )
    video_path = os.path.join(path_video_folder, video_df_row["name_video"])

    # 3) Open the video.
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: could not open {video_path}")
        cap.release()
        raise SystemExit

    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps    = cap.get(cv2.CAP_PROP_FPS)

    # 4) Create the VideoWriter.
    out_path = os.path.join(store_path, f"{video_id}.mp4")
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out_writer = cv2.VideoWriter(out_path, fourcc, fps, (width, height))

    print(f"Video {video_path}: size={width}x{height}, fps={fps}")
    print(f"Storing annotated video to: {out_path}")

    # 5) Predefine colors for each label.
    label_colors = {
        "aline": (255, 0, 0),              # Blue
        "bline": (0, 255, 0),              # Green
        "lungslidingpresent": (0, 165, 255),  # Orange
        "lungslidingabsent": (0, 0, 255),  # Red
        "lungpointpleura": (255, 255, 0),  # Cyan-ish
        "lungpoint": (0, 255, 255)       # Yellow-ish (for lungpoint vertical line)
    }
    default_color = (255, 255, 255)  # White

    frame_index = 0
    while True:
        ret, frame_img = cap.read()
        if not ret:
            break  # end of video

        # Select annotations for this frame.
        df_frame = df_video[df_video["frame"] == frame_index]

        # Draw each annotation.
        for _, row in df_frame.iterrows():
            # Get the polygon (or point) data from the specified column.
            polygon_points = row.get(polygon_col, None)
            if polygon_points is None:
                continue

            label_name = str(row.get(label_col, "unknown_label"))
            color = label_colors.get(label_name, default_color)

            if label_name == "lungpoint":
                # For lungsliding annotations, polygon_points is expected to contain a single point.
                # Draw a vertical line at that x coordinate from the top to the bottom of the frame.
                x = int(polygon_points[0][0])
                cv2.line(frame_img, (x, 0), (x, height), color, thickness=2)
                # Optionally, label the line near the top.
                cv2.putText(frame_img, label_name, (x, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            else:
                # For all other annotations, draw the polygon.
                pts_np = np.array(polygon_points, dtype=np.int32).reshape((-1, 1, 2))
                cv2.polylines(frame_img, [pts_np], isClosed=True, color=color, thickness=2)
                # Calculate the centroid of the polygon to place the label.
                cX = int(np.mean([p[0] for p in polygon_points]))
                cY = int(np.mean([p[1] for p in polygon_points]))
                cv2.putText(frame_img, label_name, (cX, cY), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            if print_bbox:
                x1, y1 = int(row["bb_min_x"]), int(row["bb_min_y"])
                x2, y2 = int(row["bb_max_x"]), int(row["bb_max_y"])
                label_name = str(row.get("label_name", "unknown_label"))

                # Get color
                color = label_colors.get(label_name, default_color)

                # Draw rectangle
                cv2.rectangle(frame_img, (x1, y1), (x2, y2), color, 2)
                # Label text
                cv2.putText(
                    frame_img,
                    label_name,
                    (x1, max(0, y1 - 5)),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5,
                    color,
                    2
                )

        # Write the annotated frame to the output video.
        out_writer.write(frame_img)
        frame_index += 1

    cap.release()
    out_writer.release()
    print("Done drawing polygons on video.")

# %%
ROOT_FOLDER_PATH = "/home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip"
STORE_FOLDER_PATH = "/home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos"

for index, row in df_videos.loc[df_videos["video_id"].isin(set(df_polygons["video_id"]))].iterrows():
    # print(vodeo_df_row)
    draw_polygons_on_video(
        df_polygons,
        ROOT_FOLDER_PATH,
        row,
        STORE_FOLDER_PATH,
        polygon_col="interp_polygon",
        label_col="polygon_label",
        print_bbox=True
    )
# Out:
# Processing PFFP3KRO
#        frame polygon_id  video_id                      name_cvat     type  \
# 18906      0   DL4HRGVZ  PFFP3KRO  014 2021-10-18_125058_159.avi  polygon
# 18933      0   P1HAR4EP  PFFP3KRO  014 2021-10-18_125058_159.avi  polygon
# 18934      1   P1HAR4EP  PFFP3KRO  014 2021-10-18_125058_159.avi  polygon
# 18907      1   DL4HRGVZ  PFFP3KRO  014 2021-10-18_125058_159.avi  polygon
# 18935      2   P1HAR4EP  PFFP3KRO  014 2021-10-18_125058_159.avi  polygon
# ...      ...        ...       ...                            ...      ...
# 20075    991   R6HGTTSC  PFFP3KRO  014 2021-10-18_125058_159.avi  polygon
# 20132    992   0774W841  PFFP3KRO  014 2021-10-18_125058_159.avi  polygon
# 20076    992   R6HGTTSC  PFFP3KRO  014 2021-10-18_125058_159.avi  polygon
# 20133    993   0774W841  PFFP3KRO  014 2021-10-18_125058_159.avi  polygon
# 20077    993   R6HGTTSC  PFFP3KRO  014 2021-10-18_125058_159.avi  polygon
#
#            polygon_label                                             points  \
# 18906  lungslidingabsent  [[556.9, 200.3], [555.3, 214.0], [487.02748781...
# 18933  lungslidingabsent  [[359.705078125, 186.0053710938], [359.7048684...
# 18934  lungslidingabsent                                               None
# 18907  lungslidingabsent                                               None
# 18935  lungslidingabsent                                               None
# ...                  ...                                                ...
# 20075  lungslidingabsent                                               None
# 20132  lungslidingabsent                                               None
# 20076  lungslidingabsent                                               None
# 20133  lungslidingabsent  [[367.6, 213.2], [366.8, 231.6], [210.44306640...
# 20077  lungslidingabsent  [[556.0, 239.8], [493.2516601563, 240.47871093...
#
#        polygon_track_id                                     interp_polygon  \
# 18906               0.0  [[556.9, 200.3], [555.3, 214.0], [487.02748781...
# 18933               1.0  [[359.705078125, 186.0053710938], [359.7048684...
# 18934               NaN  [[360.338671875, 185.926171875], [360.33846218...
# 18907               NaN  [[556.9, 200.45], [555.3, 214.32], [487.581980...
# 18935               NaN  [[360.972265625, 185.8469726563], [360.9720559...
# ...                 ...                                                ...
# 20075               NaN  [[556.09, 240.36], [493.8853515625, 241.033203...
# 20132               NaN  [[367.6, 213.28], [366.96, 231.52], [209.80942...
# 20076               NaN  [[556.045, 240.08], [493.5685058594, 240.75595...
# 20133               8.0  [[367.6, 213.2], [366.8, 231.6], [210.44306640...
# 20077               7.0  [[556.0, 239.8], [493.2516601563, 240.47871093...
#
#          bb_min_x    bb_max_x    bb_min_y    bb_max_y
# 18906  487.027488  556.900000  195.077237  214.000000
# 18933  214.552878  359.705078  186.005371  212.885189
# 18934  215.186472  360.338672  185.926172  212.805990
# 18907  487.581980  556.900000  195.389513  214.320000
# 18935  215.820066  360.972266  185.846973  212.726791
# ...           ...         ...         ...         ...
# 20075  492.485352  556.900000  222.333203  241.033203
# 20132  208.409424  367.600000  213.280000  250.405054
# 20076  492.168506  556.900000  222.055957  240.755957
# 20133  209.043066  367.600000  213.200000  250.365430
# 20077  491.851660  556.900000  221.778711  240.478711
#
# [5014 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_261/data/Lung point/014 2021-10-18_125058_159.avi: size=640x480, fps=54.0
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/PFFP3KRO.mp4
# Done drawing polygons on video.
# Processing IVIXFY95
#        frame polygon_id  video_id                                   name_cvat  \
# 14443     90   HHNIY4W6  IVIXFY95  x_20180621_161347_1853 LPNO LUNG POINT.avi
# 14444    100   5SMZBH1K  IVIXFY95  x_20180621_161347_1853 LPNO LUNG POINT.avi
# 14445    101   5SMZBH1K  IVIXFY95  x_20180621_161347_1853 LPNO LUNG POINT.avi
# 14446    102   5SMZBH1K  IVIXFY95  x_20180621_161347_1853 LPNO LUNG POINT.avi
# 14447    103   5SMZBH1K  IVIXFY95  x_20180621_161347_1853 LPNO LUNG POINT.avi
# ...      ...        ...       ...                                         ...
# 15310    994   83EQ2ROB  IVIXFY95  x_20180621_161347_1853 LPNO LUNG POINT.avi
# 15311    995   83EQ2ROB  IVIXFY95  x_20180621_161347_1853 LPNO LUNG POINT.avi
# 15312    996   83EQ2ROB  IVIXFY95  x_20180621_161347_1853 LPNO LUNG POINT.avi
# 15313    997   83EQ2ROB  IVIXFY95  x_20180621_161347_1853 LPNO LUNG POINT.avi
# 15314    998   83EQ2ROB  IVIXFY95  x_20180621_161347_1853 LPNO LUNG POINT.avi
#
#           type      polygon_label  \
# 14443  polygon  lungslidingabsent
# 14444  polygon  lungslidingabsent
# 14445  polygon  lungslidingabsent
# 14446  polygon  lungslidingabsent
# 14447  polygon  lungslidingabsent
# ...        ...                ...
# 15310  polygon  lungslidingabsent
# 15311  polygon  lungslidingabsent
# 15312  polygon  lungslidingabsent
# 15313  polygon  lungslidingabsent
# 15314  polygon  lungslidingabsent
#
#                                                   points  polygon_track_id  \
# 14443  [[344.822265625, 195.4150390625], [346.2831050...               0.0
# 14444  [[245.4609375, 193.9541015625], [246.2, 213.7]...               1.0
# 14445                                               None               NaN
# 14446                                               None               NaN
# 14447                                               None               NaN
# ...                                                  ...               ...
# 15310                                               None               NaN
# 15311                                               None               NaN
# 15312                                               None               NaN
# 15313                                               None               NaN
# 15314  [[335.32421875, 201.2607421875], [332.4, 223.2...               3.0
#
#                                           interp_polygon    bb_min_x  \
# 14443  [[344.822265625, 195.4150390625], [346.2831050...  344.822266
# 14444  [[245.4609375, 193.9541015625], [246.2, 213.7]...  245.460938
# 14445  [[247.36484375, 193.5886914063], [247.52, 213....  247.364844
# 14446  [[249.26875, 193.22328125], [248.84, 212.68], ...  248.840000
# 14447  [[251.17265625, 192.8578710938], [250.16, 212....  250.160000
# ...                                                  ...         ...
# 15310  [[338.9770507812, 201.6259765625], [341.898630...  338.977051
# 15311  [[338.0638427734, 201.5346679688], [339.523972...  338.063843
# 15312  [[337.1506347656, 201.443359375], [337.1493150...  337.149315
# 15313  [[336.2374267578, 201.3520507812], [334.774657...  334.774658
# 15314  [[335.32421875, 201.2607421875], [332.4, 223.2...  332.400000
#
#          bb_max_x    bb_min_y    bb_max_y
# 14443  488.748858  186.648402  207.105023
# 14444  469.022831  190.301370  213.700000
# 14445  469.609208  190.594436  213.190000
# 14446  470.195585  190.887503  212.680000
# 14447  470.781962  191.180569  212.170000
# ...           ...         ...         ...
# 15310  555.598174  201.625977  229.753425
# 15311  555.689498  201.534668  229.753425
# 15312  555.780822  201.443359  229.753425
# 15313  555.872146  201.352051  229.753425
# 15314  555.963470  201.260742  229.753425
#
# [4247 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_262/data/Lung point/20180621_161347_1853 LPNO LUNG POINT.avi: size=640x480, fps=54.0
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/IVIXFY95.mp4
# Done drawing polygons on video.
# Processing 1AY9XWWL
#        frame polygon_id  video_id                     name_cvat     type  \
# 1186       0   96U98OA9  1AY9XWWL  014_image_67666469659947.mp4  polygon
# 1482       0   4SXJ1RXN  1AY9XWWL  014_image_67666469659947.mp4  polygon
# 36631      0       None  1AY9XWWL  014_image_67666469659947.mp4  polygon
# 36630      0       None  1AY9XWWL  014_image_67666469659947.mp4  polygon
# 26325      0       None  1AY9XWWL  014_image_67666469659947.mp4  polygon
# ...      ...        ...       ...                           ...      ...
# 1777     295   4SXJ1RXN  1AY9XWWL  014_image_67666469659947.mp4  polygon
# 26915    295       None  1AY9XWWL  014_image_67666469659947.mp4  polygon
# 26914    295       None  1AY9XWWL  014_image_67666469659947.mp4  polygon
# 37220    295       None  1AY9XWWL  014_image_67666469659947.mp4  polygon
# 37221    295       None  1AY9XWWL  014_image_67666469659947.mp4  polygon
#
#             polygon_label                                             points  \
# 1186    lungslidingabsent  [[648.9, 240.0], [645.6, 261.4], [529.61455078...
# 1482   lungslidingpresent  [[650.59375, 240.693359375], [648.2178584337, ...
# 36631           lungpoint                  [[649.7143271685, 240.557747443]]
# 36630     lungpointpleura  [[714.7525120974, 224.059441328], [528.4096365...
# 26325           lungpoint                  [[649.7143271685, 240.557747443]]
# ...                   ...                                                ...
# 1777   lungslidingpresent  [[641.4948242188, 238.30703125], [639.08748734...
# 26915           lungpoint                 [[640.8156750455, 240.5870490941]]
# 26914     lungpointpleura  [[699.9, 231.0], [540.5556640625, 237.11699218...
# 37220     lungpointpleura  [[699.9, 231.0], [540.5556640625, 237.11699218...
# 37221           lungpoint                 [[640.8156750455, 240.5870490941]]
#
#        polygon_track_id                                     interp_polygon  \
# 1186                0.0  [[648.9, 240.0], [645.6, 261.4], [529.61455078...
# 1482                0.0  [[650.59375, 240.693359375], [648.2178584337, ...
# 36631               NaN                  [[649.7143271685, 240.557747443]]
# 36630               NaN  [[714.7525120974, 224.059441328], [528.4096365...
# 26325               NaN                  [[649.7143271685, 240.557747443]]
# ...                 ...                                                ...
# 1777                0.0  [[641.4948242188, 238.30703125], [639.08748734...
# 26915               NaN                 [[640.8156750455, 240.5870490941]]
# 26914               NaN  [[699.9, 231.0], [540.5556640625, 237.11699218...
# 37220               NaN  [[699.9, 231.0], [540.5556640625, 237.11699218...
# 37221               NaN                 [[640.8156750455, 240.5870490941]]
#
#          bb_min_x    bb_max_x    bb_min_y    bb_max_y
# 1186   528.409637  648.900000  235.284176  261.458398
# 1482   648.217858  714.752512  224.059441  260.891125
# 36631  649.714327  649.714327  240.557747  240.557747
# 36630  528.409637  714.752512  224.059441  261.458398
# 26325  649.714327  649.714327  240.557747  240.557747
# ...           ...         ...         ...         ...
# 1777   639.087487  699.900000  231.000000  262.049328
# 26915  640.815675  640.815675  240.587049  240.587049
# 26914  540.555664  699.900000  231.000000  268.842090
# 37220  540.555664  699.900000  231.000000  268.842090
# 37221  640.815675  640.815675  240.587049  240.587049
#
# [1776 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_266/data/Lung point/image_67666469659947.mp4: size=1280x720, fps=29.998026885634054
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/1AY9XWWL.mp4
# Done drawing polygons on video.
# Processing DE3IOJXQ
#        frame polygon_id  video_id                                name_cvat  \
# 10266     60   JFEGO22V  DE3IOJXQ  x211027--111948_20211027_MSK_0011lp.AVI
# 10506     60   1LA8W3U3  DE3IOJXQ  x211027--111948_20211027_MSK_0011lp.AVI
# 40201     60       None  DE3IOJXQ  x211027--111948_20211027_MSK_0011lp.AVI
# 40200     60       None  DE3IOJXQ  x211027--111948_20211027_MSK_0011lp.AVI
# 29894     60       None  DE3IOJXQ  x211027--111948_20211027_MSK_0011lp.AVI
# ...      ...        ...       ...                                      ...
# 30311    299       None  DE3IOJXQ  x211027--111948_20211027_MSK_0011lp.AVI
# 30310    299       None  DE3IOJXQ  x211027--111948_20211027_MSK_0011lp.AVI
# 40616    299       None  DE3IOJXQ  x211027--111948_20211027_MSK_0011lp.AVI
# 10718    299   7EE7Y09U  DE3IOJXQ  x211027--111948_20211027_MSK_0011lp.AVI
# 40617    299       None  DE3IOJXQ  x211027--111948_20211027_MSK_0011lp.AVI
#
#           type       polygon_label  \
# 10266  polygon   lungslidingabsent
# 10506  polygon  lungslidingpresent
# 40201  polygon           lungpoint
# 40200  polygon     lungpointpleura
# 29894  polygon     lungpointpleura
# ...        ...                 ...
# 30311  polygon           lungpoint
# 30310  polygon     lungpointpleura
# 40616  polygon     lungpointpleura
# 10718  polygon  lungslidingpresent
# 40617  polygon           lungpoint
#
#                                                   points  polygon_track_id  \
# 10266  [[377.8076171875, 376.89453125], [371.71949412...               0.0
# 10506  [[403.8051757812, 361.1865234375], [404.566588...               0.0
# 40201                 [[391.1106907567, 376.3399609491]]               NaN
# 40200  [[274.3070161401, 351.7803775392], [271.262876...               NaN
# 29894  [[274.3070161401, 351.7803775392], [271.262876...               NaN
# ...                                                  ...               ...
# 30311                 [[353.1836662207, 376.6547253626]]               NaN
# 30310  [[313.1036132813, 354.7787109375], [304.703613...               NaN
# 40616  [[313.1036132813, 354.7787109375], [304.703613...               NaN
# 10718  [[358.3725585938, 359.7431640625], [359.133971...               3.0
# 40617                 [[353.1836662207, 376.6547253626]]               NaN
#
#                                           interp_polygon    bb_min_x  \
# 10266  [[377.8076171875, 376.89453125], [371.71949412...  271.262876
# 10506  [[403.8051757812, 361.1865234375], [404.566588...  403.805176
# 40201                 [[391.1106907567, 376.3399609491]]  391.110691
# 40200  [[274.3070161401, 351.7803775392], [271.262876...  271.262876
# 29894  [[274.3070161401, 351.7803775392], [271.262876...  271.262876
# ...                                                  ...         ...
# 30311                 [[353.1836662207, 376.6547253626]]  353.183666
# 30310  [[313.1036132813, 354.7787109375], [304.703613...  304.703613
# 40616  [[313.1036132813, 354.7787109375], [304.703613...  304.703613
# 10718  [[358.3725585938, 359.7431640625], [359.133971...  358.372559
# 40617                 [[353.1836662207, 376.6547253626]]  353.183666
#
#          bb_max_x    bb_min_y    bb_max_y
# 10266  377.807617  351.780378  390.593162
# 10506  440.300000  361.186523  382.500000
# 40201  391.110691  376.339961  376.339961
# 40200  440.300000  351.780378  390.593162
# 29894  440.300000  351.780378  390.593162
# ...           ...         ...         ...
# 30311  353.183666  376.654725  376.654725
# 30310  435.200000  354.778711  378.007985
# 40616  435.200000  354.778711  378.007985
# 10718  435.200000  359.743164  378.007985
# 40617  353.183666  376.654725  376.654725
#
# [1289 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_267/data/Lung point/x211027--111948_20211027_MSK_0011lp.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/DE3IOJXQ.mp4
# Done drawing polygons on video.
# Processing Q8LX0Y1B
#        frame polygon_id  video_id                                name_cvat  \
# 22303      0   RJ2ANKJR  Q8LX0Y1B  x211027--111948_20211027_MSK_0012lp.AVI
# 22594      0   W6ZQVZ7U  Q8LX0Y1B  x211027--111948_20211027_MSK_0012lp.AVI
# 44589      0       None  Q8LX0Y1B  x211027--111948_20211027_MSK_0012lp.AVI
# 44588      0       None  Q8LX0Y1B  x211027--111948_20211027_MSK_0012lp.AVI
# 34283      0       None  Q8LX0Y1B  x211027--111948_20211027_MSK_0012lp.AVI
# ...      ...        ...       ...                                      ...
# 34863    290       None  Q8LX0Y1B  x211027--111948_20211027_MSK_0012lp.AVI
# 22884    290   W6ZQVZ7U  Q8LX0Y1B  x211027--111948_20211027_MSK_0012lp.AVI
# 45168    290       None  Q8LX0Y1B  x211027--111948_20211027_MSK_0012lp.AVI
# 22593    290   RJ2ANKJR  Q8LX0Y1B  x211027--111948_20211027_MSK_0012lp.AVI
# 45169    290       None  Q8LX0Y1B  x211027--111948_20211027_MSK_0012lp.AVI
#
#           type       polygon_label  \
# 22303  polygon   lungslidingabsent
# 22594  polygon  lungslidingpresent
# 44589  polygon           lungpoint
# 44588  polygon     lungpointpleura
# 34283  polygon           lungpoint
# ...        ...                 ...
# 34863  polygon           lungpoint
# 22884  polygon  lungslidingpresent
# 45168  polygon     lungpointpleura
# 22593  polygon   lungslidingabsent
# 45169  polygon           lungpoint
#
#                                                   points  polygon_track_id  \
# 22303  [[374.0029296875, 363.3486328125], [378.569254...               0.0
# 22594  [[382.6474609375, 363.92578125], [386.30059496...               0.0
# 44589                 [[382.3813985174, 381.5718538514]]               NaN
# 44588  [[303.2267884323, 351.1719939117], [300.182648...               NaN
# 34283                 [[382.3813985174, 381.5718538514]]               NaN
# ...                                                  ...               ...
# 34863                 [[355.2230088883, 371.3049382204]]               NaN
# 22884  [[366.177734375, 358.9091796875], [369.8308683...               0.0
# 45168  [[400.8810950521, 353.4301136053], [337.667968...               NaN
# 22593  [[337.66796875, 355.013671875], [342.234293248...               0.0
# 45169                 [[355.2230088883, 371.3049382204]]               NaN
#
#                                           interp_polygon    bb_min_x  \
# 22303  [[374.0029296875, 363.3486328125], [378.569254...  300.182648
# 22594  [[382.6474609375, 363.92578125], [386.30059496...  382.647461
# 44589                 [[382.3813985174, 381.5718538514]]  382.381399
# 44588  [[303.2267884323, 351.1719939117], [300.182648...  300.182648
# 34283                 [[382.3813985174, 381.5718538514]]  382.381399
# ...                                                  ...         ...
# 34863                 [[355.2230088883, 371.3049382204]]  355.223009
# 22884  [[366.177734375, 358.9091796875], [369.8308683...  366.177734
# 45168  [[400.8810950521, 353.4301136053], [337.667968...  307.100000
# 22593  [[337.66796875, 355.013671875], [342.234293248...  307.100000
# 45169                 [[355.2230088883, 371.3049382204]]  355.223009
#
#          bb_max_x    bb_min_y    bb_max_y
# 22303  378.569254  351.171994  382.374429
# 22594  455.706984  355.706989  381.277764
# 44589  382.381399  381.571854  381.571854
# 44588  455.706984  351.171994  382.374429
# 34283  382.381399  381.571854  381.571854
# ...           ...         ...         ...
# 34863  355.223009  371.304938  371.304938
# 22884  433.700000  353.430114  376.261163
# 45168  433.700000  353.430114  376.261163
# 22593  342.234293  355.013672  374.039468
# 45169  355.223009  371.304938  371.304938
#
# [1746 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_268/data/Lung point/x211027--111948_20211027_MSK_0012lp.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/Q8LX0Y1B.mp4
# Done drawing polygons on video.
# Processing SH8SNPMW
#        frame polygon_id  video_id                                   name_cvat  \
# 23757      0   UWWLXRT6  SH8SNPMW  x211119--131441_20211119_MSK_0001 LPAB.AVI
# 24057      0   3EVDKAT1  SH8SNPMW  x211119--131441_20211119_MSK_0001 LPAB.AVI
# 45171      0       None  SH8SNPMW  x211119--131441_20211119_MSK_0001 LPAB.AVI
# 45170      0       None  SH8SNPMW  x211119--131441_20211119_MSK_0001 LPAB.AVI
# 34865      0       None  SH8SNPMW  x211119--131441_20211119_MSK_0001 LPAB.AVI
# ...      ...        ...       ...                                         ...
# 24356    299   3EVDKAT1  SH8SNPMW  x211119--131441_20211119_MSK_0001 LPAB.AVI
# 35463    299       None  SH8SNPMW  x211119--131441_20211119_MSK_0001 LPAB.AVI
# 35462    299       None  SH8SNPMW  x211119--131441_20211119_MSK_0001 LPAB.AVI
# 45768    299       None  SH8SNPMW  x211119--131441_20211119_MSK_0001 LPAB.AVI
# 45769    299       None  SH8SNPMW  x211119--131441_20211119_MSK_0001 LPAB.AVI
#
#           type       polygon_label  \
# 23757  polygon   lungslidingabsent
# 24057  polygon  lungslidingpresent
# 45171  polygon           lungpoint
# 45170  polygon     lungpointpleura
# 34865  polygon           lungpoint
# ...        ...                 ...
# 24356  polygon  lungslidingpresent
# 35463  polygon           lungpoint
# 35462  polygon     lungpointpleura
# 45768  polygon     lungpointpleura
# 45769  polygon           lungpoint
#
#                                                   points  polygon_track_id  \
# 23757  [[346.119140625, 213.2421875], [343.3789954338...               0.0
# 24057  [[346.119140625, 213.2421875], [350.4109589041...               0.0
# 45171                     [[346.119140625, 213.2421875]]               NaN
# 45170  [[254.7945205479, 208.6757990868], [253.881278...               NaN
# 34865                     [[346.119140625, 213.2421875]]               NaN
# ...                                                  ...               ...
# 24356  [[354.41796875, 213.091796875], [358.709787029...               0.0
# 35463                  [[351.9964208196, 212.728505565]]               NaN
# 35462  [[552.3, 208.6], [298.80234375, 209.9693359375...               NaN
# 45768  [[552.3, 208.6], [298.80234375, 209.9693359375...               NaN
# 45769                  [[351.9964208196, 212.728505565]]               NaN
#
#                                           interp_polygon    bb_min_x  \
# 23757  [[346.119140625, 213.2421875], [343.3789954338...  253.881279
# 24057  [[346.119140625, 213.2421875], [350.4109589041...  346.119141
# 45171                     [[346.119140625, 213.2421875]]  346.119141
# 45170  [[254.7945205479, 208.6757990868], [253.881278...  253.881279
# 34865                     [[346.119140625, 213.2421875]]  346.119141
# ...                                                  ...         ...
# 24356  [[354.41796875, 213.091796875], [358.709787029...  354.417969
# 35463                  [[351.9964208196, 212.728505565]]  351.996421
# 35462  [[552.3, 208.6], [298.80234375, 209.9693359375...  296.802344
# 45768  [[552.3, 208.6], [298.80234375, 209.9693359375...  296.802344
# 45769                  [[351.9964208196, 212.728505565]]  351.996421
#
#          bb_max_x    bb_min_y    bb_max_y
# 23757  346.119141  208.675799  231.506849
# 24057  523.926941  209.771689  236.255708
# 45171  346.119141  213.242188  213.242188
# 45170  523.926941  208.675799  236.255708
# 34865  346.119141  213.242188  213.242188
# ...           ...         ...         ...
# 24356  552.300000  208.600000  236.105317
# 35463  351.996421  212.728506  212.728506
# 35462  552.300000  208.600000  236.105317
# 45768  552.300000  208.600000  236.105317
# 45769  351.996421  212.728506  212.728506
#
# [1800 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_269/data/Lung point/x211119--131441_20211119_MSK_0001 LPAB.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/SH8SNPMW.mp4
# Done drawing polygons on video.
# Processing GHOX1FZE
#        frame polygon_id  video_id                                 name_cvat  \
# 12717      0   NSEYWQ9C  GHOX1FZE  x211119--131441_20211119_MSK_0002LPB.AVI
# 13008      0   58YCUM3L  GHOX1FZE  x211119--131441_20211119_MSK_0002LPB.AVI
# 41109      0       None  GHOX1FZE  x211119--131441_20211119_MSK_0002LPB.AVI
# 41108      0       None  GHOX1FZE  x211119--131441_20211119_MSK_0002LPB.AVI
# 30803      0       None  GHOX1FZE  x211119--131441_20211119_MSK_0002LPB.AVI
# ...      ...        ...       ...                                       ...
# 31383    290       None  GHOX1FZE  x211119--131441_20211119_MSK_0002LPB.AVI
# 13298    290   58YCUM3L  GHOX1FZE  x211119--131441_20211119_MSK_0002LPB.AVI
# 41688    290       None  GHOX1FZE  x211119--131441_20211119_MSK_0002LPB.AVI
# 13007    290   NSEYWQ9C  GHOX1FZE  x211119--131441_20211119_MSK_0002LPB.AVI
# 41689    290       None  GHOX1FZE  x211119--131441_20211119_MSK_0002LPB.AVI
#
#           type       polygon_label  \
# 12717  polygon   lungslidingabsent
# 13008  polygon  lungslidingpresent
# 41109  polygon           lungpoint
# 41108  polygon     lungpointpleura
# 30803  polygon           lungpoint
# ...        ...                 ...
# 31383  polygon           lungpoint
# 13298  polygon  lungslidingpresent
# 41688  polygon     lungpointpleura
# 13007  polygon   lungslidingabsent
# 41689  polygon           lungpoint
#
#                                                   points  polygon_track_id  \
# 12717  [[354.1, 227.8], [359.71875, 241.875], [295.0,...               0.0
# 13008  [[360.65625, 230.625], [360.65625, 241.875], [...               0.0
# 41109                              [[360.1875, 241.875]]               NaN
# 41108  [[540.65625, 210.0], [296.0, 224.1], [295.0, 2...               NaN
# 30803                              [[360.1875, 241.875]]               NaN
# ...                                                  ...               ...
# 31383                 [[316.9145044361, 224.8659744218]]               NaN
# 13298  [[317.4467773438, 224.9653320312], [317.446777...               0.0
# 41688  [[516.2, 208.2], [251.9184570312, 219.81943359...               NaN
# 13007  [[316.6, 223.6], [264.1184570313, 219.81943359...               0.0
# 41689                 [[316.9145044361, 224.8659744218]]               NaN
#
#                                           interp_polygon    bb_min_x  \
# 12717  [[354.1, 227.8], [359.71875, 241.875], [295.0,...  295.000000
# 13008  [[360.65625, 230.625], [360.65625, 241.875], [...  360.656250
# 41109                              [[360.1875, 241.875]]  360.187500
# 41108  [[540.65625, 210.0], [296.0, 224.1], [295.0, 2...  295.000000
# 30803                              [[360.1875, 241.875]]  360.187500
# ...                                                  ...         ...
# 31383                 [[316.9145044361, 224.8659744218]]  316.914504
# 13298  [[317.4467773438, 224.9653320312], [317.446777...  317.446777
# 41688  [[516.2, 208.2], [251.9184570312, 219.81943359...  250.918457
# 13007  [[316.6, 223.6], [264.1184570313, 219.81943359...  250.918457
# 41689                 [[316.9145044361, 224.8659744218]]  316.914504
#
#          bb_max_x    bb_min_y    bb_max_y
# 12717  359.718750  224.100000  241.875000
# 13008  547.218750  210.000000  241.875000
# 41109  360.187500  241.875000  241.875000
# 41108  547.218750  210.000000  241.875000
# 30803  360.187500  241.875000  241.875000
# ...           ...         ...         ...
# 31383  316.914504  224.865974  224.865974
# 13298  517.300000  208.200000  237.200000
# 41688  517.300000  208.200000  238.600000
# 13007  316.600000  219.819434  238.600000
# 41689  316.914504  224.865974  224.865974
#
# [1746 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_270/data/Lung point/x211119--131441_20211119_MSK_0002LPB.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/GHOX1FZE.mp4
# Done drawing polygons on video.
# Processing Q1Z8FQL0
#        frame polygon_id  video_id                                  name_cvat  \
# 21436      0   ZVZIBHO0  Q1Z8FQL0  x211119--131441_20211119_MSK_0003LPAB.AVI
# 21725      0   1E1ZXJ7I  Q1Z8FQL0  x211119--131441_20211119_MSK_0003LPAB.AVI
# 33746      0       None  Q1Z8FQL0  x211119--131441_20211119_MSK_0003LPAB.AVI
# 33747      0       None  Q1Z8FQL0  x211119--131441_20211119_MSK_0003LPAB.AVI
# 44052      0       None  Q1Z8FQL0  x211119--131441_20211119_MSK_0003LPAB.AVI
# ...      ...        ...       ...                                        ...
# 34281    288       None  Q1Z8FQL0  x211119--131441_20211119_MSK_0003LPAB.AVI
# 34280    288       None  Q1Z8FQL0  x211119--131441_20211119_MSK_0003LPAB.AVI
# 22302    288   AS80J1AA  Q1Z8FQL0  x211119--131441_20211119_MSK_0003LPAB.AVI
# 22013    288   1E1ZXJ7I  Q1Z8FQL0  x211119--131441_20211119_MSK_0003LPAB.AVI
# 44587    288       None  Q1Z8FQL0  x211119--131441_20211119_MSK_0003LPAB.AVI
#
#           type       polygon_label  \
# 21436   points           lungpoint
# 21725  polygon   lungslidingabsent
# 33746   points     lungpointpleura
# 33747   points           lungpoint
# 44052   points     lungpointpleura
# ...        ...                 ...
# 34281   points           lungpoint
# 34280   points     lungpointpleura
# 22302  polygon  lungslidingpresent
# 22013  polygon   lungslidingabsent
# 44587   points           lungpoint
#
#                                                   points  polygon_track_id  \
# 21436                  [[411.8720703125, 210.501953125]]               0.0
# 21725  [[323.2880859375, 215.068359375], [329.6803652...               0.0
# 33746  [[525.1141552511, 184.0182648402], [400.913242...               NaN
# 33747                 [[412.6572684226, 215.8963735286]]               NaN
# 44052  [[525.1141552511, 184.0182648402], [400.913242...               NaN
# ...                                                  ...               ...
# 34281                 [[400.9547231391, 201.0705940381]]               NaN
# 34280  [[529.6803652968, 187.6712328767], [405.479492...               NaN
# 22302  [[405.4794921875, 199.54296875], [410.04566210...               0.0
# 22013  [[330.59375, 208.67578125], [332.4200913242, 2...               0.0
# 44587                 [[400.9547231391, 201.0705940381]]               NaN
#
#                                           interp_polygon    bb_min_x  \
# 21436                  [[411.8720703125, 210.501953125]]  411.872070
# 21725  [[323.2880859375, 215.068359375], [329.6803652...  323.288086
# 33746  [[525.1141552511, 184.0182648402], [400.913242...  323.288086
# 33747                 [[412.6572684226, 215.8963735286]]  412.657268
# 44052  [[525.1141552511, 184.0182648402], [400.913242...  323.288086
# ...                                                  ...         ...
# 34281                 [[400.9547231391, 201.0705940381]]  400.954723
# 34280  [[529.6803652968, 187.6712328767], [405.479492...  330.593750
# 22302  [[405.4794921875, 199.54296875], [410.04566210...  405.479492
# 22013  [[330.59375, 208.67578125], [332.4200913242, 2...  330.593750
# 44587                 [[400.9547231391, 201.0705940381]]  400.954723
#
#          bb_max_x    bb_min_y    bb_max_y
# 21436  411.872070  210.501953  210.501953
# 21725  411.000000  197.716895  224.200913
# 33746  525.114155  184.018265  224.200913
# 33747  412.657268  215.896374  215.896374
# 44052  525.114155  184.018265  224.200913
# ...           ...         ...         ...
# 34281  400.954723  201.070594  201.070594
# 34280  534.246575  187.671233  225.114155
# 22302  534.246575  187.671233  216.894977
# 22013  396.347032  202.283105  225.114155
# 44587  400.954723  201.070594  201.070594
#
# [1939 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_271/data/Lung point/x211119--131441_20211119_MSK_0003LPAB.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/Q1Z8FQL0.mp4
# Done drawing polygons on video.
# Processing 0CJ4LA0L
#        frame polygon_id  video_id                                  name_cvat  \
# 0          0   6T8OQ8BX  0CJ4LA0L  x211119--131441_20211119_MSK_0004 LPB.AVI
# 36065      0       None  0CJ4LA0L  x211119--131441_20211119_MSK_0004 LPB.AVI
# 36064      0       None  0CJ4LA0L  x211119--131441_20211119_MSK_0004 LPB.AVI
# 25759      0       None  0CJ4LA0L  x211119--131441_20211119_MSK_0004 LPB.AVI
# 25758      0       None  0CJ4LA0L  x211119--131441_20211119_MSK_0004 LPB.AVI
# ...      ...        ...       ...                                        ...
# 574      299   ZMIJ1H7J  0CJ4LA0L  x211119--131441_20211119_MSK_0004 LPB.AVI
# 26323    299       None  0CJ4LA0L  x211119--131441_20211119_MSK_0004 LPB.AVI
# 26322    299       None  0CJ4LA0L  x211119--131441_20211119_MSK_0004 LPB.AVI
# 36628    299       None  0CJ4LA0L  x211119--131441_20211119_MSK_0004 LPB.AVI
# 36629    299       None  0CJ4LA0L  x211119--131441_20211119_MSK_0004 LPB.AVI
#
#           type       polygon_label  \
# 0      polygon   lungslidingabsent
# 36065  polygon           lungpoint
# 36064  polygon     lungpointpleura
# 25759  polygon           lungpoint
# 25758  polygon     lungpointpleura
# ...        ...                 ...
# 574    polygon  lungslidingpresent
# 26323  polygon           lungpoint
# 26322  polygon     lungpointpleura
# 36628  polygon     lungpointpleura
# 36629  polygon           lungpoint
#
#                                                   points  polygon_track_id  \
# 0      [[437.1181640625, 223.267578125], [437.1182141...               0.0
# 36065                 [[438.1645549517, 226.3330106596]]               NaN
# 36064  [[540.1538981904, 207.8352782006], [295.058346...               NaN
# 25759                 [[438.1645549517, 226.3330106596]]               NaN
# 25758  [[540.1538981904, 207.8352782006], [295.058346...               NaN
# ...                                                  ...               ...
# 574    [[348.8969726562, 245.0903320312], [350.482585...               2.0
# 26323                 [[349.1084720116, 259.8977515218]]               NaN
# 26322  [[537.6, 203.8], [289.0, 249.5], [294.1, 262.8...               NaN
# 36628  [[537.6, 203.8], [289.0, 249.5], [294.1, 262.8...               NaN
# 36629                 [[349.1084720116, 259.8977515218]]               NaN
#
#                                           interp_polygon    bb_min_x  \
# 0      [[437.1181640625, 223.267578125], [437.1182141...  295.058346
# 36065                 [[438.1645549517, 226.3330106596]]  438.164555
# 36064  [[540.1538981904, 207.8352782006], [295.058346...  295.058346
# 25759                 [[438.1645549517, 226.3330106596]]  438.164555
# 25758  [[540.1538981904, 207.8352782006], [295.058346...  295.058346
# ...                                                  ...         ...
# 574    [[348.8969726562, 245.0903320312], [350.482585...  348.896973
# 26323                 [[349.1084720116, 259.8977515218]]  349.108472
# 26322  [[537.6, 203.8], [289.0, 249.5], [294.1, 262.8...  289.000000
# 36628  [[537.6, 203.8], [289.0, 249.5], [294.1, 262.8...  289.000000
# 36629                 [[349.1084720116, 259.8977515218]]  349.108472
#
#          bb_max_x    bb_min_y    bb_max_y
# 0      437.118214  223.267578  250.537798
# 36065  438.164555  226.333011  226.333011
# 36064  545.967360  207.835278  250.537798
# 25759  438.164555  226.333011  226.333011
# 25758  545.967360  207.835278  250.537798
# ...           ...         ...         ...
# 574    538.800000  203.800000  262.001870
# 26323  349.108472  259.897752  259.897752
# 26322  538.800000  203.800000  262.800000
# 36628  538.800000  203.800000  262.800000
# 36629  349.108472  259.897752  259.897752
#
# [1707 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_272/data/Lung point/x211119--131441_20211119_MSK_0004 LPB.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/0CJ4LA0L.mp4
# Done drawing polygons on video.
# Processing YOBBHM8M
#        frame polygon_id  video_id                                name_cvat  \
# 24858      0   LCW57DW3  YOBBHM8M  x220425--091211_20220425_MSK_0004lp.AVI
# 25158      0   EJEK041Y  YOBBHM8M  x220425--091211_20220425_MSK_0004lp.AVI
# 45771      0       None  YOBBHM8M  x220425--091211_20220425_MSK_0004lp.AVI
# 45770      0       None  YOBBHM8M  x220425--091211_20220425_MSK_0004lp.AVI
# 35465      0       None  YOBBHM8M  x220425--091211_20220425_MSK_0004lp.AVI
# ...      ...        ...       ...                                      ...
# 25457    299   EJEK041Y  YOBBHM8M  x220425--091211_20220425_MSK_0004lp.AVI
# 36063    299       None  YOBBHM8M  x220425--091211_20220425_MSK_0004lp.AVI
# 36062    299       None  YOBBHM8M  x220425--091211_20220425_MSK_0004lp.AVI
# 46368    299       None  YOBBHM8M  x220425--091211_20220425_MSK_0004lp.AVI
# 46369    299       None  YOBBHM8M  x220425--091211_20220425_MSK_0004lp.AVI
#
#           type       polygon_label  \
# 24858  polygon   lungslidingabsent
# 25158  polygon  lungslidingpresent
# 45771  polygon           lungpoint
# 45770  polygon     lungpointpleura
# 35465  polygon           lungpoint
# ...        ...                 ...
# 25457  polygon  lungslidingpresent
# 36063  polygon           lungpoint
# 36062  polygon     lungpointpleura
# 46368  polygon     lungpointpleura
# 46369  polygon           lungpoint
#
#                                                   points  polygon_track_id  \
# 24858  [[403.7890625, 239.8491210938], [406.431252510...               0.0
# 25158  [[401.2731445313, 242.3693359375], [404.673144...               0.0
# 45771                  [[405.4369251107, 254.893600484]]               NaN
# 45770  [[426.5141207667, 236.677950976], [403.7890625...               NaN
# 35465                  [[405.4369251107, 254.893600484]]               NaN
# ...                                                  ...               ...
# 25457  [[399.4469726563, 242.3693359375], [402.846972...               0.0
# 36063                 [[403.5844699296, 255.9376528822]]               NaN
# 36062  [[424.6869723292, 239.4172087885], [399.446972...               NaN
# 46368  [[424.6869723292, 239.4172087885], [399.446972...               NaN
# 46369                 [[403.5844699296, 255.9376528822]]               NaN
#
#                                           interp_polygon    bb_min_x  \
# 24858  [[403.7890625, 239.8491210938], [406.431252510...  403.789062
# 25158  [[401.2731445313, 242.3693359375], [404.673144...  309.480830
# 45771                  [[405.4369251107, 254.893600484]]  405.436925
# 45770  [[426.5141207667, 236.677950976], [403.7890625...  309.480830
# 35465                  [[405.4369251107, 254.893600484]]  405.436925
# ...                                                  ...         ...
# 25457  [[399.4469726563, 242.3693359375], [402.846972...  307.654658
# 36063                 [[403.5844699296, 255.9376528822]]  403.584470
# 36062  [[424.6869723292, 239.4172087885], [399.446972...  307.654658
# 46368  [[424.6869723292, 239.4172087885], [399.446972...  307.654658
# 46369                 [[403.5844699296, 255.9376528822]]  403.584470
#
#          bb_max_x    bb_min_y    bb_max_y
# 24858  460.138281  236.677951  254.646833
# 25158  404.673145  242.369336  272.699307
# 45771  405.436925  254.893600  254.893600
# 45770  460.138281  236.677951  272.699307
# 35465  405.436925  254.893600  254.893600
# ...           ...         ...         ...
# 25457  402.846973  242.369336  272.699307
# 36063  403.584470  255.937653  255.937653
# 36062  458.311133  239.417209  272.699307
# 46368  458.311133  239.417209  272.699307
# 46369  403.584470  255.937653  255.937653
#
# [1800 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_273/data/Lung point/x220425--091211_20220425_MSK_0004lp.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/YOBBHM8M.mp4
# Done drawing polygons on video.
# Processing BL506TPN
#        frame polygon_id  video_id                                 name_cvat  \
# 8035       0   E58UHK5N  BL506TPN  x220425--091211_20220425_MSK_0005lpq.AVI
# 8436       0   RWIRAHRE  BL506TPN  x220425--091211_20220425_MSK_0005lpq.AVI
# 8335       0   MSQ1ORQX  BL506TPN  x220425--091211_20220425_MSK_0005lpq.AVI
# 28695      0       None  BL506TPN  x220425--091211_20220425_MSK_0005lpq.AVI
# 39000      0       None  BL506TPN  x220425--091211_20220425_MSK_0005lpq.AVI
# ...      ...        ...       ...                                       ...
# 8334     299   E58UHK5N  BL506TPN  x220425--091211_20220425_MSK_0005lpq.AVI
# 8915     299   LEP1MA82  BL506TPN  x220425--091211_20220425_MSK_0005lpq.AVI
# 8735     299   RWIRAHRE  BL506TPN  x220425--091211_20220425_MSK_0005lpq.AVI
# 39598    299       None  BL506TPN  x220425--091211_20220425_MSK_0005lpq.AVI
# 39599    299       None  BL506TPN  x220425--091211_20220425_MSK_0005lpq.AVI
#
#           type       polygon_label  \
# 8035   polygon   lungslidingabsent
# 8436   polygon  lungslidingpresent
# 8335   polygon  lungslidingpresent
# 28695  polygon           lungpoint
# 39000  polygon     lungpointpleura
# ...        ...                 ...
# 8334   polygon   lungslidingabsent
# 8915   polygon  lungslidingpresent
# 8735   polygon  lungslidingpresent
# 39598  polygon     lungpointpleura
# 39599  polygon           lungpoint
#
#                                                   points  polygon_track_id  \
# 8035   [[386.69921875, 239.05859375], [386.0654490107...               0.0
# 8436   [[381.6259765625, 240.9619140625], [383.528665...               1.0
# 8335   [[503.1, 239.4], [507.7, 255.7], [467.2, 251.5...               0.0
# 28695                 [[384.8316954854, 253.6954397579]]               NaN
# 39000  [[464.6, 237.6], [427.9675623692, 238.01327946...               NaN
# ...                                                  ...               ...
# 8334   [[358.677734375, 241.7275390625], [358.0439646...               0.0
# 8915   [[502.4162109375, 238.9004882813], [500.616210...               2.0
# 8735   [[352.3875, 246.707421875], [329.4706483761, 2...               1.0
# 39598  [[451.1107421875, 237.1385742188], [414.478304...               NaN
# 39599                 [[356.6157323178, 258.4121561965]]               NaN
#
#                                           interp_polygon    bb_min_x  \
# 8035   [[386.69921875, 239.05859375], [386.0654490107...  386.065449
# 8436   [[381.6259765625, 240.9619140625], [383.528665...  310.596144
# 8335   [[503.1, 239.4], [507.7, 255.7], [467.2, 251.5...  427.967562
# 28695                 [[384.8316954854, 253.6954397579]]  384.831695
# 39000  [[464.6, 237.6], [427.9675623692, 238.01327946...  310.596144
# ...                                                  ...         ...
# 8334   [[358.677734375, 241.7275390625], [358.0439646...  358.043965
# 8915   [[502.4162109375, 238.9004882813], [500.616210...  414.478305
# 8735   [[352.3875, 246.707421875], [329.4706483761, 2...  311.478418
# 39598  [[451.1107421875, 237.1385742188], [414.478304...  311.478418
# 39599                 [[356.6157323178, 258.4121561965]]  356.615732
#
#          bb_max_x    bb_min_y    bb_max_y
# 8035   422.800000  238.424658  255.547945
# 8436   383.528666  240.961914  264.426687
# 8335   507.700000  237.600000  258.300000
# 28695  384.831695  253.695440  253.695440
# 39000  507.700000  237.600000  264.426687
# ...           ...         ...         ...
# 8334   408.600000  238.600000  258.216891
# 8915   502.416211  237.138574  257.838574
# 8735   355.187500  246.707422  264.708984
# 39598  502.416211  237.138574  264.708984
# 39599  356.615732  258.412156  258.412156
#
# [2081 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung point/task_274/data/Lung point/x220425--091211_20220425_MSK_0005lpq.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/BL506TPN.mp4
# Done drawing polygons on video.
# Processing DC8PMFR4
#        frame polygon_id  video_id                                name_cvat  \
# 9666       0   MFT3WNUY  DC8PMFR4  x220425--091211_20220425_MSK_0011lp.AVI
# 9966       0   21F3JMVF  DC8PMFR4  x220425--091211_20220425_MSK_0011lp.AVI
# 39601      0       None  DC8PMFR4  x220425--091211_20220425_MSK_0011lp.AVI
# 39600      0       None  DC8PMFR4  x220425--091211_20220425_MSK_0011lp.AVI
# 29295      0       None  DC8PMFR4  x220425--091211_20220425_MSK_0011lp.AVI
# ...      ...        ...       ...                                      ...
# 10265    299   21F3JMVF  DC8PMFR4  x220425--091211_20220425_MSK_0011lp.AVI
# 29893    299       None  DC8PMFR4  x220425--091211_20220425_MSK_0011lp.AVI
# 29892    299       None  DC8PMFR4  x220425--091211_20220425_MSK_0011lp.AVI
# 40198    299       None  DC8PMFR4  x220425--091211_20220425_MSK_0011lp.AVI
# 40199    299       None  DC8PMFR4  x220425--091211_20220425_MSK_0011lp.AVI
#
#           type       polygon_label  \
# 9666   polygon   lungslidingabsent
# 9966   polygon  lungslidingpresent
# 39601  polygon           lungpoint
# 39600  polygon     lungpointpleura
# 29295  polygon           lungpoint
# ...        ...                 ...
# 10265  polygon  lungslidingpresent
# 29893  polygon           lungpoint
# 29892  polygon     lungpointpleura
# 40198  polygon     lungpointpleura
# 40199  polygon           lungpoint
#
#                                                   points  polygon_track_id  \
# 9666   [[403.9599609375, 241.39453125], [406.07432775...               0.0
# 9966   [[398.61640625, 244.05625], [371.173828125, 24...               0.0
# 39601                  [[401.444284303, 243.4277377786]]               NaN
# 39600  [[446.2400642652, 239.8093184509], [403.959960...               NaN
# 29295                  [[401.444284303, 243.4277377786]]               NaN
# ...                                                  ...               ...
# 10265  [[358.4513671875, 246.698828125], [331.0087890...               0.0
# 29893                 [[365.5548349813, 245.8870637224]]               NaN
# 29892  [[371.9638671875, 238.9985351562], [296.160546...               NaN
# 40198  [[371.9638671875, 238.9985351562], [296.160546...               NaN
# 40199                 [[365.5548349813, 245.8870637224]]               NaN
#
#                                           interp_polygon    bb_min_x  \
# 9666   [[403.9599609375, 241.39453125], [406.07432775...  403.959961
# 9966   [[398.61640625, 244.05625], [371.173828125, 24...  318.800000
# 39601                  [[401.444284303, 243.4277377786]]  401.444284
# 39600  [[446.2400642652, 239.8093184509], [403.959960...  318.800000
# 29295                  [[401.444284303, 243.4277377786]]  401.444284
# ...                                                  ...         ...
# 10265  [[358.4513671875, 246.698828125], [331.0087890...  296.160547
# 29893                 [[365.5548349813, 245.8870637224]]  365.554835
# 29892  [[371.9638671875, 238.9985351562], [296.160546...  296.160547
# ...
# 8032    297   1BOCSFXU  AVMTJNI4  x220819--071841_20220819_MSK_0002bs.AVI
# 8033    298   1BOCSFXU  AVMTJNI4  x220819--071841_20220819_MSK_0002bs.AVI
# 8034    299   1BOCSFXU  AVMTJNI4  x220819--071841_20220819_MSK_0002bs.AVI
#
#          type       polygon_label  \
# 7735  polygon  lungslidingpresent
# 7736  polygon  lungslidingpresent
# 7737  polygon  lungslidingpresent
# 7738  polygon  lungslidingpresent
# 7739  polygon  lungslidingpresent
# ...       ...                 ...
# 8030  polygon  lungslidingpresent
# 8031  polygon  lungslidingpresent
# 8032  polygon  lungslidingpresent
# 8033  polygon  lungslidingpresent
# 8034  polygon  lungslidingpresent
#
#                                                  points  polygon_track_id  \
# 7735  [[355.12890625, 266.46875], [356.6514459665, 2...               0.0
# 7736                                               None               NaN
# 7737                                               None               NaN
# 7738                                               None               NaN
# 7739                                               None               NaN
# ...                                                 ...               ...
# 8030                                               None               NaN
# 8031                                               None               NaN
# 8032                                               None               NaN
# 8033                                               None               NaN
# 8034  [[317.8380859375, 271.0336914062], [318.538085...               0.0
#
#                                          interp_polygon    bb_min_x  \
# 7735  [[355.12890625, 266.46875], [356.6514459665, 2...  355.128906
# 7736  [[352.806015625, 266.771875], [354.7063013699,...  352.806016
# 7737  [[350.483125, 267.075], [352.7611567732, 276.8...  350.483125
# 7738  [[348.160234375, 267.378125], [350.8160121766,...  348.160234
# 7739  [[345.83734375, 267.68125], [348.8708675799, 2...  345.837344
# ...                                                 ...         ...
# 8030  [[318.5143012153, 270.0189344618], [319.214301...  318.514301
# 8031  [[318.3452473958, 270.2726236979], [319.045247...  318.345247
# 8032  [[318.1761935764, 270.526312934], [318.8761935...  318.176194
# 8033  [[318.0071397569, 270.7800021701], [318.707139...  318.007140
# 8034  [[317.8380859375, 271.0336914062], [318.538085...  317.838086
#
#         bb_max_x    bb_min_y    bb_max_y
# 7735  470.045662  245.920852  276.362253
# 7736  470.843709  245.993899  276.586027
# 7737  471.641756  246.066946  276.809802
# 7738  472.439803  246.139993  277.033577
# 7739  473.237850  246.213040  277.257352
# ...          ...         ...         ...
# 8030  458.524123  243.362150  282.918934
# 8031  458.355070  243.615839  283.172624
# 8032  458.186016  243.869529  283.426313
# 8033  458.016962  244.123218  283.680002
# 8034  457.847908  244.376907  283.933691
#
# [300 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung sliding present (aj ine znaky - radiol. klin.)/task_351/data/lung sliding present (aj ine znaky - radiol. klin.)/x220819--071841_20220819_MSK_0002bs.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/AVMTJNI4.mp4
# Done drawing polygons on video.
# Processing KLU169HJ
#        frame polygon_id  video_id                               name_cvat  \
# 16806      0   LRG8TN85  KLU169HJ  x220819--071841_20220819_MSK_0003s.AVI
# 16807      1   LRG8TN85  KLU169HJ  x220819--071841_20220819_MSK_0003s.AVI
# 16808      2   LRG8TN85  KLU169HJ  x220819--071841_20220819_MSK_0003s.AVI
# 16809      3   LRG8TN85  KLU169HJ  x220819--071841_20220819_MSK_0003s.AVI
# 16810      4   LRG8TN85  KLU169HJ  x220819--071841_20220819_MSK_0003s.AVI
# ...      ...        ...       ...                                     ...
# 17101    295   LRG8TN85  KLU169HJ  x220819--071841_20220819_MSK_0003s.AVI
# 17102    296   LRG8TN85  KLU169HJ  x220819--071841_20220819_MSK_0003s.AVI
# 17103    297   LRG8TN85  KLU169HJ  x220819--071841_20220819_MSK_0003s.AVI
# 17104    298   LRG8TN85  KLU169HJ  x220819--071841_20220819_MSK_0003s.AVI
# 17105    299   LRG8TN85  KLU169HJ  x220819--071841_20220819_MSK_0003s.AVI
#
#           type       polygon_label  \
# 16806  polygon  lungslidingpresent
# 16807  polygon  lungslidingpresent
# 16808  polygon  lungslidingpresent
# 16809  polygon  lungslidingpresent
# 16810  polygon  lungslidingpresent
# ...        ...                 ...
# 17101  polygon  lungslidingpresent
# 17102  polygon  lungslidingpresent
# 17103  polygon  lungslidingpresent
# 17104  polygon  lungslidingpresent
# 17105  polygon  lungslidingpresent
#
#                                                   points  polygon_track_id  \
# 16806  [[351.12109375, 247.6201171875], [348.58447488...               0.0
# 16807                                               None               NaN
# 16808                                               None               NaN
# 16809                                               None               NaN
# 16810                                               None               NaN
# ...                                                  ...               ...
# 17101                                               None               NaN
# 17102                                               None               NaN
# 17103                                               None               NaN
# 17104                                               None               NaN
# 17105  [[338.1538085938, 242.529296875], [335.6171897...               0.0
#
#                                           interp_polygon    bb_min_x  \
# 16806  [[351.12109375, 247.6201171875], [348.58447488...  348.584475
# 16807  [[350.7737304687, 247.93671875], [348.23711160...  348.237112
# 16808  [[350.4263671875, 248.2533203125], [347.889748...  347.889748
# 16809  [[350.0790039062, 248.569921875], [347.5423850...  347.542385
# 16810  [[349.731640625, 248.8865234375], [347.1950217...  347.195022
# ...                                                  ...         ...
# 17101  [[338.1538085938, 242.529296875], [335.6171897...  335.617190
# 17102  [[338.1538085938, 242.529296875], [335.6171897...  335.617190
# 17103  [[338.1538085938, 242.529296875], [335.6171897...  335.617190
# 17104  [[338.1538085938, 242.529296875], [335.6171897...  335.617190
# 17105  [[338.1538085938, 242.529296875], [335.6171897...  335.617190
#
#          bb_max_x    bb_min_y    bb_max_y
# 16806  470.984272  242.546930  272.988331
# 16807  470.636909  242.863532  273.304932
# 16808  470.289545  243.180134  273.621534
# 16809  469.942182  243.496735  273.938135
# 16810  469.594819  243.813337  274.254737
# ...           ...         ...         ...
# 17101  459.245801  240.016406  267.897510
# 17102  459.245801  240.016406  267.897510
# 17103  459.245801  240.016406  267.897510
# 17104  459.245801  240.016406  267.897510
# 17105  459.245801  240.016406  267.897510
#
# [300 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung sliding present (aj ine znaky - radiol. klin.)/task_352/data/lung sliding present (aj ine znaky - radiol. klin.)/x220819--071841_20220819_MSK_0003s.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/KLU169HJ.mp4
# Done drawing polygons on video.
# Processing KOCCGKE0
#        frame polygon_id  video_id                                name_cvat  \
# 17106      0   7ECRJV9U  KOCCGKE0  x220819--071841_20220819_MSK_0004as.AVI
# 17107      1   7ECRJV9U  KOCCGKE0  x220819--071841_20220819_MSK_0004as.AVI
# 17108      2   7ECRJV9U  KOCCGKE0  x220819--071841_20220819_MSK_0004as.AVI
# 17109      3   7ECRJV9U  KOCCGKE0  x220819--071841_20220819_MSK_0004as.AVI
# 17110      4   7ECRJV9U  KOCCGKE0  x220819--071841_20220819_MSK_0004as.AVI
# ...      ...        ...       ...                                      ...
# 17401    295   7ECRJV9U  KOCCGKE0  x220819--071841_20220819_MSK_0004as.AVI
# 17402    296   7ECRJV9U  KOCCGKE0  x220819--071841_20220819_MSK_0004as.AVI
# 17403    297   7ECRJV9U  KOCCGKE0  x220819--071841_20220819_MSK_0004as.AVI
# 17404    298   7ECRJV9U  KOCCGKE0  x220819--071841_20220819_MSK_0004as.AVI
# 17405    299   7ECRJV9U  KOCCGKE0  x220819--071841_20220819_MSK_0004as.AVI
#
#           type       polygon_label  \
# 17106  polygon  lungslidingpresent
# 17107  polygon  lungslidingpresent
# 17108  polygon  lungslidingpresent
# 17109  polygon  lungslidingpresent
# 17110  polygon  lungslidingpresent
# ...        ...                 ...
# 17401  polygon  lungslidingpresent
# 17402  polygon  lungslidingpresent
# 17403  polygon  lungslidingpresent
# 17404  polygon  lungslidingpresent
# 17405  polygon  lungslidingpresent
#
#                                                   points  polygon_track_id  \
# 17106  [[328.48046875, 254.279296875], [327.212075088...               0.0
# 17107                                               None               NaN
# 17108                                               None               NaN
# 17109                                               None               NaN
# 17110                                               None               NaN
# ...                                                  ...               ...
# 17401                                               None               NaN
# 17402                                               None               NaN
# 17403                                               None               NaN
# 17404                                               None               NaN
# 17405  [[323.7534179688, 254.5756835938], [322.485024...               0.0
#
#                                           interp_polygon    bb_min_x  \
# 17106  [[328.48046875, 254.279296875], [327.212075088...  327.212075
# 17107  [[328.8956542969, 254.3089355469], [327.627260...  327.627261
# 17108  [[329.3108398438, 254.3385742188], [328.042446...  328.042446
# 17109  [[329.7260253906, 254.3682128906], [328.457631...  328.457632
# 17110  [[330.1412109375, 254.3978515625], [328.872817...  328.872817
# ...                                                  ...         ...
# 17401  [[323.7534179688, 254.5756835938], [322.485024...  322.485024
# 17402  [[323.7534179688, 254.5756835938], [322.485024...  322.485024
# 17403  [[323.7534179688, 254.5756835938], [322.485024...  322.485024
# 17404  [[323.7534179688, 254.5756835938], [322.485024...  322.485024
# 17405  [[323.7534179688, 254.5756835938], [322.485024...  322.485024
#
#          bb_max_x    bb_min_y    bb_max_y
# 17106  448.343480  254.279297  277.744800
# 17107  448.758666  254.308936  277.774438
# 17108  449.173852  254.338574  277.804077
# 17109  449.589037  254.368213  277.833716
# 17110  450.004223  254.397852  277.863354
# ...           ...         ...         ...
# 17401  443.616430  254.575684  278.041186
# 17402  443.616430  254.575684  278.041186
# 17403  443.616430  254.575684  278.041186
# 17404  443.616430  254.575684  278.041186
# 17405  443.616430  254.575684  278.041186
#
# [300 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung sliding present (aj ine znaky - radiol. klin.)/task_353/data/lung sliding present (aj ine znaky - radiol. klin.)/x220819--071841_20220819_MSK_0004as.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/KOCCGKE0.mp4
# Done drawing polygons on video.
# Processing T7EUVCFF
#        frame polygon_id  video_id                               name_cvat  \
# 24357      0   TLFIS7I3  T7EUVCFF  x220819--071841_20220819_MSK_0005s.AVI
# 24558      0   SV1JY5UB  T7EUVCFF  x220819--071841_20220819_MSK_0005s.AVI
# 24559      1   SV1JY5UB  T7EUVCFF  x220819--071841_20220819_MSK_0005s.AVI
# 24358      1   TLFIS7I3  T7EUVCFF  x220819--071841_20220819_MSK_0005s.AVI
# 24359      2   TLFIS7I3  T7EUVCFF  x220819--071841_20220819_MSK_0005s.AVI
# ...      ...        ...       ...                                     ...
# 24853    295   SV1JY5UB  T7EUVCFF  x220819--071841_20220819_MSK_0005s.AVI
# 24854    296   SV1JY5UB  T7EUVCFF  x220819--071841_20220819_MSK_0005s.AVI
# 24855    297   SV1JY5UB  T7EUVCFF  x220819--071841_20220819_MSK_0005s.AVI
# 24856    298   SV1JY5UB  T7EUVCFF  x220819--071841_20220819_MSK_0005s.AVI
# 24857    299   SV1JY5UB  T7EUVCFF  x220819--071841_20220819_MSK_0005s.AVI
#
#           type       polygon_label  \
# 24357  polygon               aline
# 24558  polygon  lungslidingpresent
# 24559  polygon  lungslidingpresent
# 24358  polygon               aline
# 24359  polygon               aline
# ...        ...                 ...
# 24853  polygon  lungslidingpresent
# 24854  polygon  lungslidingpresent
# 24855  polygon  lungslidingpresent
# 24856  polygon  lungslidingpresent
# 24857  polygon  lungslidingpresent
#
#                                                   points  polygon_track_id  \
# 24357  [[379.861328125, 345.033203125], [379.33240317...               0.0
# 24558  [[360.7607421875, 210.3935546875], [359.492643...               0.0
# 24559                                               None               NaN
# 24358                                               None               NaN
# 24359                                               None               NaN
# ...                                                  ...               ...
# 24853                                               None               NaN
# 24854                                               None               NaN
# 24855                                               None               NaN
# 24856                                               None               NaN
# 24857  [[371.1706054688, 202.5033203125], [366.814160...               0.0
#
#                                           interp_polygon    bb_min_x  \
# 24357  [[379.861328125, 345.033203125], [379.33240317...  379.332403
# 24558  [[360.7607421875, 210.3935546875], [359.492643...  359.492643
# 24559  [[360.3182128906, 210.3938476563], [359.050114...  359.050114
# 24358  [[379.7469773065, 345.0197172619], [379.218052...  379.218052
# 24359  [[379.6326264881, 345.0062313988], [379.103701...  379.103702
# ...                                                  ...         ...
# 24853  [[371.1706054688, 202.5033203125], [366.814160...  366.814160
# 24854  [[371.1706054688, 202.5033203125], [366.814160...  366.814160
# 24855  [[371.1706054688, 202.5033203125], [366.814160...  366.814160
# 24856  [[371.1706054688, 202.5033203125], [366.814160...  366.814160
# 24857  [[371.1706054688, 202.5033203125], [366.814160...  366.814160
#
#          bb_max_x    bb_min_y    bb_max_y
# 24357  420.026636  345.032978  354.017419
# 24558  448.280061  204.051243  224.345510
# 24559  447.837532  204.051536  224.345803
# 24358  419.912285  345.019492  354.003933
# 24359  419.797935  345.006006  353.990448
# ...           ...         ...         ...
# 24853  453.670605  202.503320  220.825002
# 24854  453.670605  202.503320  220.825002
# 24855  453.670605  202.503320  220.825002
# 24856  453.670605  202.503320  220.825002
# 24857  453.670605  202.503320  220.825002
#
# [501 rows x 13 columns]
# Video /home/mh731nk/_data/experiments_tmp/data/revision_8/cvat_project_raw_unzip/USG - Lung sliding present (aj ine znaky - radiol. klin.)/task_354/data/lung sliding present (aj ine znaky - radiol. klin.)/x220819--071841_20220819_MSK_0005s.AVI: size=800x600, fps=30.303
# Storing annotated video to: /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/T7EUVCFF.mp4
# Done drawing polygons on video.

# %% [markdown]
# # Video encode
# I want to play video in browser and in oirignal encoding it is not possible

# %%
import os
import subprocess

def encode_all_videos(source_folder, dest_folder):
    """
    Re-encode all .mp4 videos in 'source_folder' using H.264 and
    store them in 'dest_folder' with the same filename.
    """
    # Make sure the destination folder exists
    os.makedirs(dest_folder, exist_ok=True)

    # Loop over all .mp4 files in the source folder
    for filename in os.listdir(source_folder):
        if filename.lower().endswith(".mp4"):
            print(filename)
            input_path = os.path.join(source_folder, filename)
            output_path = os.path.join(dest_folder, filename)

            print(f"Re-encoding {input_path} -> {output_path}")

            # Build the ffmpeg command
            cmd = [
                "/usr/bin/ffmpeg",
                "-y",                # Overwrite output if exists
                "-i", input_path,    # Input file
                "-vcodec", "libx264",
                "-crf", "23",
                "-preset", "medium",
                "-pix_fmt", "yuv420p",
                output_path
            ]

            result = subprocess.run(
                cmd,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=True  # If using Python 3.7+, for string output
            )
            if result.returncode != 0:
                print("FFmpeg failed, see error below:")
                print(result.stderr)
            else:
                print("FFmpeg succeeded!")

    print("Done!")

# %%
source_folder = "/home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos"
dest_folder   = "/home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos_encoded"

encode_all_videos(source_folder, dest_folder)
# Out:
# GWQZGDD5.mp4
# Re-encoding /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/GWQZGDD5.mp4 -> /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos_encoded/GWQZGDD5.mp4
# FFmpeg succeeded!
# IVIXFY95.mp4
# Re-encoding /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/IVIXFY95.mp4 -> /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos_encoded/IVIXFY95.mp4
# FFmpeg succeeded!
# SC26GDR7.mp4
# Re-encoding /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/SC26GDR7.mp4 -> /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos_encoded/SC26GDR7.mp4
# FFmpeg succeeded!
# DC8PMFR4.mp4
# Re-encoding /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/DC8PMFR4.mp4 -> /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos_encoded/DC8PMFR4.mp4
# FFmpeg succeeded!
# 3SF3MPYK.mp4
# Re-encoding /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/3SF3MPYK.mp4 -> /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos_encoded/3SF3MPYK.mp4
# FFmpeg succeeded!
# 3O90ZZJG.mp4
# Re-encoding /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/3O90ZZJG.mp4 -> /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos_encoded/3O90ZZJG.mp4
# FFmpeg succeeded!
# CEXTQHHA.mp4
# Re-encoding /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos/CEXTQHHA.mp4 -> /home/mh731nk/_data/experiments_tmp/data/revision_8/over_draw_videos/02/videos_encoded/CEXTQHHA.mp4
